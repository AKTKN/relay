# %% [markdown]
# # Characterizing the performance of relay-bp with the rotated surface code
# In this notebook we tune Relay-BP for the rotated surface code under circuit-level noise.
#
# This guide assumes you have installed Relay-BP as described in the [Readme](../README.md) with the Stim option. For comparison we
# also assume Pymatching is installed. For gradient free optimization of Relay parameters we use [`nevergrad`](https://github.com/facebookresearch/nevergrad) which should also be installed.
#
# To install:
#
# ```bash
# pip install ".[stim]" pymatching nevergrad seaborn
# ```

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import itertools
from pathlib import Path

import matplotlib.pyplot as plt
import stim
import sinter
import numpy as np
from scipy.sparse import csc_matrix

from relay_bp.stim import SinterDecoder_RelayBP, SinterDecoder_MemBP, SinterDecoder_MSLBP, sinter_decoders

import sys
sys.path.append(str(Path("../tests").resolve()))
import testdata

# %% [markdown]
# ## Let's set the notebook parameters

# %% [markdown]
# We will store our data to a directory to avoid having to re-run simulations more than once

# %%
data_dir = Path("data")
data_dir.mkdir(parents=True, exist_ok=True)

# Enable testing parameters, set to True for a quick check with a smaller code
test = True

# If set False the default parameters will be used and only the PER vs. LER plot will be generated
# If test is set to True, highly unoptimized results will be obtained
optimize = True

# Use saved data
load_data = True

# Save data from any runs we perform
save_data = True

# %% [markdown]
# Now let's choose the parameters which we will use to control the notebook execution

# %%
# X/Z basis circuits to be characterized together in post-processing

notebook_str = "rotated_surface_code"
circuits = ["rotated_surface_code_memory_Z"]
noise_model = "uniform_circuit"

# Distance of the code
if test:
    distance = 5
else:
    distance = 11

# Number of circuit rounds
rounds = distance

opt_error_rate = 0.001

if test:
    error_rates = [0.001, 0.002, 0.003]
else:
    error_rates = [0.001, 0.002, 0.003, 0.004, 0.005]

def rough_select_num_shots(p: float) -> int:
    """Number of shots for a given error rate"""
    if p >= 0.005:
        return 500
    elif p < 0.005 and p >= 0.004:
        return 500
    elif p < 0.004 and p >= 0.003:
        return 1_000
    elif p < 0.003 and p >= 0.002:
        return 5_000
    return 10_000

def normal_select_num_shots(p: float) -> int:
    """Number of shots for a given error rate"""
    if p >= 0.005:
        return 3_000
    elif p < 0.005 and p >= 0.004:
        return 5_000
    elif p < 0.004 and p >= 0.003:
        return 10_000
    elif p < 0.003 and p >= 0.002:
        return 100_000
    return 1_000_000

def fine_select_num_shots(p: float) -> int:
    """Number of shots for a given error rate"""
    if p >= 0.005:
        return 5_000
    elif p < 0.005 and p >= 0.004:
        return 10_000
    elif p < 0.004 and p >= 0.003:
        return 100_000
    elif p < 0.003 and p >= 0.002:
        return 1_000_000
    return 10_000_000

if test:
    select_num_shots = rough_select_num_shots
else:
    select_num_shots = fine_select_num_shots

# %%
# Some good defaults
gamma0 = 0.65
alpha = 1.
relay_gamma_dist_interval = [-0.25453802248, 0.98518104204]

if test:
    msl_max_iter = 200
    relay_num_sets = 60
    relay_num_pre_iter = 80
    relay_set_max_iter = 60
    relay_stop_nconv = 1
else:
    msl_max_iter = 10000
    relay_num_sets = 300
    relay_num_pre_iter = 80
    relay_set_max_iter = 60
    relay_stop_nconv = 5


def build_relay_params(**kwargs):
    params = {
        "alpha": alpha,
        "gamma0": gamma0,
        "gamma_dist_interval": relay_gamma_dist_interval,
        "num_sets": relay_num_sets,
        "pre_iter": relay_num_pre_iter,
        "set_max_iter": relay_set_max_iter,
        "stop_nconv": relay_stop_nconv,
    }
    if kwargs:
        params.update(kwargs)
    return params

def build_msl_params(**kwargs):
    params = {
        "alpha": alpha,
        "max_iter": msl_max_iter,
    }
    if kwargs:
        params.update(kwargs)
    return params

def build_mem_params(**kwargs):
    params = {
        "alpha": alpha,
        "max_iter": msl_max_iter,
        "gamma0": gamma0,
    }
    if kwargs:
        params.update(kwargs)
    return params

default_relay_params = build_relay_params()
default_msl_params = build_msl_params()
default_mem_params = build_mem_params()

# %% [markdown]
# ## We now select the decoders we want to make available

# %%
default_custom_decoders = sinter_decoders(**build_relay_params())

all_decoders = list(sinter_decoders().keys()) + ["pymatching"]
all_decoders.remove("harmonized-bp")
xz_only_decoders = ["pymatching"]
default_decoders = all_decoders


print(f"The decoders we will compare {default_decoders}")
# Out:
# The decoders we will compare ['relay-bp', 'mem-bp', 'msl-bp', 'pymatching']

# %% [markdown]
# We add a bit of custom machinery to avoid regenerating data depending on how we want to use the notebook

# %%
def load_path(experiment_name) -> Path | None:
    if load_data and not save_data:
        path = data_dir / f"{notebook_str}_{experiment_name}.csv"
        if path.exists():
            return [data_dir / f"{notebook_str}_{experiment_name}.csv"]
    return []

def save_path(experiment_name) -> Path | None:
    if save_data:
        return data_dir / f"{notebook_str}_{experiment_name}.csv"
    return None

# %% [markdown]
# We also add a wrapper around circuit generation to enable different noise models

# %%
import multiprocessing

from relay_bp.stim.sinter.utils import write_stats

num_notebook_workers = multiprocessing.cpu_count()


def sinter_collect(tasks, exp_name, num_workers=None, custom_decoders=None, start_batch_size=10_000, save=True, load=True, consolidate_samples=True, **sinter_kwargs):
    if num_workers is None:
        num_workers = num_notebook_workers

    if custom_decoders is None:
        custom_decoders = default_custom_decoders

    save_file = save_path(exp_name) if save else None
    samples = sinter.collect(
        tasks=tasks,
        num_workers=num_workers, 
        existing_data_filepaths=load_path(exp_name) if load else [],
        save_resume_filepath=save_file,
        custom_decoders=custom_decoders,
        start_batch_size=start_batch_size,
        **sinter_kwargs
    )

    if consolidate_samples and save:
        write_stats(samples, save_file)

    return samples

# %% [markdown]
# ## Tuning Relay-BP memory factor
#
# Relay has several parameters such as the uniform memory factor for the initial set run, and relay gamma distribution values that should be tuned to the specific code.
#
# We explore this below. First we explore the initial uniform factor and then we use gradient free optimization to tune the relay distribution parameters.

# %%
# Generates surface code circuit tasks using Stim's circuit generation.

if test:
    membp_gamma0s = np.linspace(0, 1, 11)
    membp_error_rates = [opt_error_rate]
    membp_distances = [distance]
    membp_sweep_max_iter = 80
    membp_sweep_xyz = False
else:
    # Sweep out phase transition in more detail
    membp_gamma0s = np.linspace(0, 1, 21).tolist()
    membp_error_rates = [opt_error_rate]
    membp_distances = [distance]
    membp_sweep_max_iter = 80
    membp_sweep_xyz = True
    

def generate_gamma0_tasks(decoder_params):
    for d in membp_distances:
        for membp_error_rate in membp_error_rates:
            for circuit_name in circuits:
                circ = testdata.get_test_circuit(circuit_name, distance=d, rounds=d, error_rate=membp_error_rate)
                if not membp_sweep_xyz:
                    circ = testdata.filter_detectors_by_basis(circ, circuit_name[-1])
                dem = circ.detector_error_model(decompose_errors=not membp_sweep_xyz)
                yield sinter.Task(
                    circuit=circ,
                    detector_error_model=dem,
                    decoder="mem-bp",
                    json_metadata={
                        'circuit': circuit_name,
                        'p': membp_error_rate,
                        'd': d,
                        'r': d,
                        'decoder_params': decoder_params,
                        'xyz': membp_sweep_xyz,
                    },
                    collection_options=sinter.CollectionOptions(max_shots=rough_select_num_shots(membp_error_rate))
                )

def collect_gamma0_sweep_samples():
    samples = []
    for gamma0 in membp_gamma0s:
        print(f"Starting collection of membp gamma0: {gamma0:.2f}")
        decoder_params = build_mem_params(gamma0=gamma0, max_iter=membp_sweep_max_iter)
        circuit_samples = sinter_collect(
            generate_gamma0_tasks(decoder_params), 
            exp_name="gamma0_sweep", 
            custom_decoders={"mem-bp": SinterDecoder_MemBP(**decoder_params)},
            save=save_data,
            load=load_data,
        )
        synthesized_samples = testdata.synthesize_joint_samples(circuit_samples, circuits)
        samples += circuit_samples

    return samples

if optimize:
    gamma0_sweep_samples = collect_gamma0_sweep_samples()
# Out:
# Starting collection of membp gamma0: 0.00
# Starting collection of membp gamma0: 0.10
# Starting collection of membp gamma0: 0.20
# Starting collection of membp gamma0: 0.30
# Starting collection of membp gamma0: 0.40
# Starting collection of membp gamma0: 0.50
# Starting collection of membp gamma0: 0.60
# Starting collection of membp gamma0: 0.70
# Starting collection of membp gamma0: 0.80
# Starting collection of membp gamma0: 0.90
# Starting collection of membp gamma0: 1.00

# %%
if optimize:
    min_gamma0_trial = None
    min_gamma0_ler = 1.
    min_gamma0 = 1.
    for sample in gamma0_sweep_samples:
        if sample.json_metadata["p"] != membp_error_rates[0] or sample.json_metadata["d"] != membp_distances[-1] or sample.json_metadata["xyz"] != membp_sweep_xyz:
            continue
        ler = sample.errors/sample.shots
        if ler < min_gamma0_ler:
            min_gamma0_ler = ler
            min_gamma0 = sample.json_metadata["decoder_params"]["gamma0"]
            min_gamma0_trial = sample
    
    print(f"The minimum gamma0 is: {min_gamma0:.2f} with logical error rate: {min_gamma0_ler}")
# Out:
# The minimum gamma0 is: 0.30 with logical error rate: 0.0003

# %%
if optimize:
    import matplotlib
    
    cmap = matplotlib.colormaps.get_cmap('Spectral')
    
    def group_func(stat):
        return {
            "label": f"""d={stat.json_metadata["d"]}, p={stat.json_metadata["p"]}, xyz={membp_sweep_xyz}""",
            "color": cmap(stat.json_metadata["d"]/max(membp_distances)),
            "linestyle": "-",
        }
    
    def filter_func_gen(p):
        def filter_func(stat):
            return ("mem-bp" == stat.decoder and 
                    stat.json_metadata["p"] == p and
                    stat.json_metadata["d"] in membp_distances and
                    stat.json_metadata["xyz"] == membp_sweep_xyz
                   )
        return filter_func
    
    # Render a matplotlib plot of the data.
    fig, axs = plt.subplots(1, len(membp_error_rates), figsize=(10, 6))
    if not isinstance(axs, list):
        axs = [axs]
    
    for ax, error_rate in zip(axs, membp_error_rates):
        sinter.plot_error_rate(
            ax=ax,
            stats=gamma0_sweep_samples,
            group_func=group_func,
            failure_units_per_shot_func=lambda stats: stats.json_metadata["d"],
            x_func=lambda stat: stat.json_metadata["decoder_params"]["gamma0"],
            filter_func=filter_func_gen(error_rate),
        )
    
        ax.set_yscale("log")
        ax.set_ylim(1e-5, 1)
        ax.grid()
        ax.set_ylabel("Logical Error Probability (per round/qubit)")
        ax.set_xlabel("gamma0 (memory factor)")
        ax.legend()
    
    plt.suptitle(f"{notebook_str} - Logical Error Rate (per round) vs Memory Factor")
    
    plt.show()

# %% [markdown]
# ## Optimizing Relay parameters
#
# Below we optimize Relay parameters.
# We will use a gradient free optimizer.

# %%
# First some useful helper functions to calculate logical error rates.
def get_trial_stderr_per(errors, shots, target):
    LER_est = errors/shots
    if LER_est == 0.:
        return 0., 1., 10000
    standard_error_per = np.sqrt(LER_est*(1-LER_est)/shots) / LER_est

    addl_shots = additional_shots(target, standard_error_per, shots)
    return LER_est, standard_error_per, addl_shots


def additional_shots(target, current, current_shots):
    scale_factor = (current/target)**2
    return int(np.ceil(current_shots*scale_factor))

# %% [markdown]
# ### Tuning with gradient free optimization
# Below we use [nevergrad](https://github.com/facebookresearch/nevergrad) to tune the distribution hyperparameters.

# %%
import nevergrad as ng

import relay_bp

# We reduce the number of sets to speed up training
if test:
    opt_budget = 100
    opt_max_shots = int(1E4)
    opt_per_stderr = 0.5
    opt_initial_shots = 100
    opt_num_sets = 100
    opt_num_pre_iter = relay_num_pre_iter
    opt_set_max_iter = relay_set_max_iter
    opt_stop_nconv = 1
    opt_xyz = False
    verbosity = 2
else:
    opt_budget = 100
    opt_max_shots = int(2E5)
    opt_per_stderr = 0.2
    opt_initial_shots = 250
    opt_num_sets = 100
    opt_num_pre_iter = relay_num_pre_iter
    opt_set_max_iter = relay_set_max_iter
    opt_stop_nconv = 1
    opt_xyz = True
    verbosity = 2 

seed = 0

"""We set up the decoder manually without Sinter to utilize its parallel
batch decoder as it is typically more performant than sinter's Python
multiprocessing.

we also reuse shots across cost function calls
to avoid additional noise in the optimization and improve performance.
"""

if optimize:
    detector_data = {}
    obs_data = {}
    dem_matrices = {}
    check_matrix = {}
    observable_matrix = {}
    error_priors = {}
    for circuit_name in circuits:
        opt_circuit = testdata.get_test_circuit(circuit_name, distance=distance, rounds=rounds, error_rate=opt_error_rate)
        if opt_xyz:
            opt_dem = opt_circuit.detector_error_model()
        else:
            opt_circuit = testdata.filter_detectors_by_basis(opt_circuit, circuit_name[-1])
            opt_dem = opt_circuit.detector_error_model()

        dem_matrices[circuit_name] = relay_bp.stim.CheckMatrices.from_dem(opt_dem)
        check_matrix[circuit_name] = dem_matrices[circuit_name].check_matrix
        observable_matrix[circuit_name] = dem_matrices[circuit_name].observables_matrix
        error_priors[circuit_name] = dem_matrices[circuit_name].error_priors
        
        sampler = opt_dem.compile_sampler()
        circ_detector_data, circ_obs_data, _ = sampler.sample(opt_max_shots, return_errors=False)
        circ_detector_data = circ_detector_data.astype(np.uint8)
        circ_obs_data = circ_obs_data.astype(np.uint8)

        # Only use samples that fail mem-bp to train Relay for training performance improvement
        mem_bp_decoder = relay_bp.MinSumBPDecoderF64(
                    check_matrix[circuit_name],
                    error_priors=error_priors[circuit_name],
                    gamma0=min_gamma0,
                    max_iter=opt_num_pre_iter,   
                )
        
        mem_bp_observable_decoder = relay_bp.ObservableDecoderRunner(
            mem_bp_decoder,
            observable_matrix[circuit_name],
            include_decode_result=False,
        )

        decoded_obs_data = mem_bp_observable_decoder.decode_observables_batch(circ_detector_data, parallel=True)
        failures = np.any(circ_obs_data != decoded_obs_data, axis=1)
        failure_locs = np.where(failures)

        if verbosity == 2:
            print(f"For {circuit_name} and {opt_max_shots} there are {np.sum(failures)} failing mem-bp samples to train with.")
        detector_data[circuit_name] = circ_detector_data[failure_locs].astype(np.uint8)
        obs_data[circuit_name] = circ_obs_data[failure_locs].astype(np.uint8)
    
    def gen_cost_function(
        check_matrix, 
        observable_matrix, 
        error_priors, 
        detector_data, 
        obs_data, 
        max_stderr_per_tolerance=opt_per_stderr, 
        initial_shots=opt_initial_shots,
        gamma0=min_gamma0,
        max_shots=opt_max_shots,
        pre_iter=opt_num_pre_iter,
        num_sets=opt_num_sets,
        set_max_iter=opt_set_max_iter,
        stop_nconv=opt_stop_nconv,
        
        
    ):
        def cost_function(gamma_dist_min, gamma_dist_max):
            gamma_dist_interval = (gamma_dist_min, gamma_dist_max)
            if verbosity == 2:
                print(f"Starting cost evaluation for gamma_dist_interval={gamma_dist_interval}") 
    
            observable_decoders = {}
            for circuit_name in circuits:   
                decoder = relay_bp.RelayDecoderF64(
                    check_matrix[circuit_name],
                    error_priors=error_priors[circuit_name],
                    gamma0=gamma0,
                    pre_iter=pre_iter,
                    num_sets=num_sets,
                    set_max_iter=set_max_iter,
                    gamma_dist_interval=gamma_dist_interval,
                    stop_nconv=stop_nconv,
                
                )
        
                observable_decoders[circuit_name] = relay_bp.ObservableDecoderRunner(
                    decoder,
                    observable_matrix[circuit_name],
                    include_decode_result=False,
                )
    
            errors = {circuit_name: 0 for circuit_name in circuits}
            curr_stderr_per = 1.
            curr_shots = initial_shots
            prev_shots = 0

            marginals = []
            for circuit_name in circuits:
                # Decode the observable errors
                decoded_obs_data = observable_decoders[circuit_name].decode_observables_batch(detector_data[circuit_name], parallel=True)
    
                errors[circuit_name] += np.sum(np.any(obs_data[circuit_name] != decoded_obs_data, axis=1))
                
                marginals.append(errors[circuit_name]/max_shots)

            prob_at_least_one_error = testdata.utils.prob_at_least_one_error(marginals)
            
            total_errors = int(prob_at_least_one_error*max_shots)
            
            cost, curr_stderr_per, addl_shots = get_trial_stderr_per(total_errors, max_shots, max_stderr_per_tolerance)

            per_round_cost = cost/rounds
            if verbosity == 2:
                print(f"for (gamma_dist_interval={gamma_dist_interval}) ler per round, per qubit={per_round_cost}")
                print(f"errors: {errors}, total (mem-bp failing) shots: {max_shots}, percent error: {100*curr_stderr_per}%")

            return per_round_cost 
            
        return cost_function
    
    relay_params = ng.p.Instrumentation(
        gamma_dist_min=ng.p.Scalar(init=relay_gamma_dist_interval[0], lower=-0.5, upper=0.5),
        gamma_dist_max=ng.p.Scalar(init=relay_gamma_dist_interval[1], lower=0.0, upper=1.0),
    )
    
    def ensure_gamma_interval_ordered(vals):
        param_dict = vals[1]
        return param_dict["gamma_dist_min"] < param_dict["gamma_dist_max"]
    
    relay_params.register_cheap_constraint(ensure_gamma_interval_ordered)
    
    optimizer = ng.optimizers.TwoPointsDE(parametrization=relay_params, budget=opt_budget)
    optimizer.register_callback("tell", ng.callbacks.ProgressBar())
    cost_function = gen_cost_function(check_matrix, observable_matrix, error_priors, detector_data, obs_data)
    recommendation = optimizer.minimize(cost_function, verbosity=verbosity, batch_mode=False)
    
    opt_gamma0 = min_gamma0
    opt_gamma_dist_interval = [recommendation[1]["gamma_dist_min"].value, recommendation[1]["gamma_dist_max"].value]
    final_cost_function = gen_cost_function(
        check_matrix, observable_matrix, error_priors, detector_data, obs_data, 
        gamma0=opt_gamma0, pre_iter=relay_num_pre_iter, 
        num_sets=relay_num_sets, set_max_iter=relay_set_max_iter, stop_nconv=relay_stop_nconv,
    )
    cost_ler = cost_function(*opt_gamma_dist_interval)
    opt_ler = final_cost_function(*opt_gamma_dist_interval)
    
    print(f"For d={distance} relay-bp optimization with p={opt_error_rate}")
    print(f"Expedited cost function logical error rate: {cost_ler}")
    print(f"Full cost function logical error rate: {opt_ler}")
    print(f"optimized parameters - opt_gamma0: {opt_gamma0}, opt_gamma_dist_interval: {opt_gamma_dist_interval}")
# Out:
# 100%|██████████| 100/100 [03:29<00:00,  2.09s/it]
# For rotated_surface_code_memory_Z and 10000 there are 8 failing mem-bp samples to train with.
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.42125778560031435, 0.3134642928260136)
# for (gamma_dist_interval=(-0.42125778560031435, 0.3134642928260136)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
#  11%|█         | 11/100 [00:00<00:00, 109.17it/s]
# Updating fitness with value 0.0
# 99 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.42125778560031435, 'gamma_dist_max': 0.3134642928260136})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.03682892307519896, 0.5181850852381498)
# for (gamma_dist_interval=(0.03682892307519896, 0.5181850852381498)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 98 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.03682892307519896, 'gamma_dist_max': 0.5181850852381498})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.17668247757651184, 1.0)
# for (gamma_dist_interval=(-0.17668247757651184, 1.0)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 97 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.17668247757651184, 'gamma_dist_max': 1.0})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.20523844113990133, 0.9743058242203034)
# for (gamma_dist_interval=(-0.20523844113990133, 0.9743058242203034)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 96 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.20523844113990133, 'gamma_dist_max': 0.9743058242203034})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.20143585565767333, 0.8040307025302458)
# for (gamma_dist_interval=(-0.20143585565767333, 0.8040307025302458)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 95 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.20143585565767333, 'gamma_dist_max': 0.8040307025302458})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.3584869621887966, 0.9520303793547091)
# for (gamma_dist_interval=(-0.3584869621887966, 0.9520303793547091)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 94 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.3584869621887966, 'gamma_dist_max': 0.9520303793547091})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.34976767443745327, 0.970819719828564)
# for (gamma_dist_interval=(-0.34976767443745327, 0.970819719828564)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 93 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.34976767443745327, 'gamma_dist_max': 0.970819719828564})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.4958485346308518, 0.9500968941582677)
# for (gamma_dist_interval=(0.4958485346308518, 0.9500968941582677)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 92 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.4958485346308518, 'gamma_dist_max': 0.9500968941582677})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.22852125314846042, 0.9838853709297903)
# for (gamma_dist_interval=(-0.22852125314846042, 0.9838853709297903)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 91 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.22852125314846042, 'gamma_dist_max': 0.9838853709297903})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.3131212892669844, 0.9983702058169581)
# for (gamma_dist_interval=(-0.3131212892669844, 0.9983702058169581)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 90 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.3131212892669844, 'gamma_dist_max': 0.9983702058169581})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.4933694621873648, 0.2779676328659516)
# for (gamma_dist_interval=(-0.4933694621873648, 0.2779676328659516)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 89 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.4933694621873648, 'gamma_dist_max': 0.2779676328659516})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.3545001989240284, 0.7098461458064454)
# for (gamma_dist_interval=(-0.3545001989240284, 0.7098461458064454)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 88 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.3545001989240284, 'gamma_dist_max': 0.7098461458064454})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.341059244410575, 0.5869618037323157)
# for (gamma_dist_interval=(-0.341059244410575, 0.5869618037323157)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 87 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.341059244410575, 'gamma_dist_max': 0.5869618037323157})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.21516498007703147, 0.9444238857483479)
# for (gamma_dist_interval=(-0.21516498007703147, 0.9444238857483479)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 86 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.21516498007703147, 'gamma_dist_max': 0.9444238857483479})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.3097813259608428, 0.4858922049080289)
# for (gamma_dist_interval=(-0.3097813259608428, 0.4858922049080289)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 85 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.3097813259608428, 'gamma_dist_max': 0.4858922049080289})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.2758327343322202, 0.7730902981875317)
# for (gamma_dist_interval=(-0.2758327343322202, 0.7730902981875317)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 84 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.2758327343322202, 'gamma_dist_max': 0.7730902981875317})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.22141937856606045, 0.5153525305935713)
# for (gamma_dist_interval=(-0.22141937856606045, 0.5153525305935713)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 83 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.22141937856606045, 'gamma_dist_max': 0.5153525305935713})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.2276579798043581, 0.8170961801683946)
# for (gamma_dist_interval=(-0.2276579798043581, 0.8170961801683946)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 82 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.2276579798043581, 'gamma_dist_max': 0.8170961801683946})>
# Launching 1 jobs with new suggestions
#  24%|██▍       | 24/100 [00:00<00:00, 120.36it/s]
# Starting cost evaluation for gamma_dist_interval=(0.13360903373899113, 0.8477591387761292)
# for (gamma_dist_interval=(0.13360903373899113, 0.8477591387761292)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 81 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.13360903373899113, 'gamma_dist_max': 0.8477591387761292})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.19161905111089167, 0.9238821870701306)
# for (gamma_dist_interval=(-0.19161905111089167, 0.9238821870701306)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 80 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.19161905111089167, 'gamma_dist_max': 0.9238821870701306})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.22541391192848848, 0.38470375319003147)
# for (gamma_dist_interval=(-0.22541391192848848, 0.38470375319003147)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 79 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.22541391192848848, 'gamma_dist_max': 0.38470375319003147})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.1772723999033102, 0.9139156708984988)
# for (gamma_dist_interval=(-0.1772723999033102, 0.9139156708984988)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 78 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.1772723999033102, 'gamma_dist_max': 0.9139156708984988})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.23884537662882763, 0.992807300043457)
# for (gamma_dist_interval=(-0.23884537662882763, 0.992807300043457)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 77 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.23884537662882763, 'gamma_dist_max': 0.992807300043457})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.31854073831518587, 0.629913131236924)
# for (gamma_dist_interval=(-0.31854073831518587, 0.629913131236924)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 76 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.31854073831518587, 'gamma_dist_max': 0.629913131236924})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.476029844820118, 0.9244078291035531)
# for (gamma_dist_interval=(-0.476029844820118, 0.9244078291035531)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 75 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.476029844820118, 'gamma_dist_max': 0.9244078291035531})>
# Launching 1 jobs with new suggestions
#  37%|███▋      | 37/100 [00:00<00:00, 115.66it/s]
# Starting cost evaluation for gamma_dist_interval=(-0.4391147561940923, 0.9935314016937673)
# for (gamma_dist_interval=(-0.4391147561940923, 0.9935314016937673)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 74 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.4391147561940923, 'gamma_dist_max': 0.9935314016937673})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.1471134024504407, 0.9732084001274801)
# for (gamma_dist_interval=(-0.1471134024504407, 0.9732084001274801)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 73 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.1471134024504407, 'gamma_dist_max': 0.9732084001274801})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.39394381781393795, 0.9503079138499277)
# for (gamma_dist_interval=(-0.39394381781393795, 0.9503079138499277)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 72 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.39394381781393795, 'gamma_dist_max': 0.9503079138499277})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.21137150744470606, 0.5043988948054107)
# for (gamma_dist_interval=(-0.21137150744470606, 0.5043988948054107)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 71 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.21137150744470606, 'gamma_dist_max': 0.5043988948054107})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.08384807373931924, 0.9931504681735577)
# for (gamma_dist_interval=(-0.08384807373931924, 0.9931504681735577)) ler per round, per qubit=2e-05
# errors: {'rotated_surface_code_memory_Z': np.int64(2)}, total (mem-bp failing) shots: 10000, percent error: 99.99499987499374%
# Updating fitness with value 2e-05
# 70 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.21137150744470606, 'gamma_dist_max': 0.5043988948054107})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.05285601676252409, 0.31346429282601374)
# for (gamma_dist_interval=(-0.05285601676252409, 0.31346429282601374)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 69 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.05285601676252409, 'gamma_dist_max': 0.31346429282601374})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.08449037743232214, 0.5659761940395274)
# for (gamma_dist_interval=(0.08449037743232214, 0.5659761940395274)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 68 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.08449037743232214, 'gamma_dist_max': 0.5659761940395274})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.09489621401299361, 0.876415327218419)
# for (gamma_dist_interval=(0.09489621401299361, 0.876415327218419)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 67 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.09489621401299361, 'gamma_dist_max': 0.876415327218419})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.42157064952357026, 0.9743058242203034)
# for (gamma_dist_interval=(0.42157064952357026, 0.9743058242203034)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 66 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.42157064952357026, 'gamma_dist_max': 0.9743058242203034})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.20143585565767333, 0.4235191565189487)
# for (gamma_dist_interval=(-0.20143585565767333, 0.4235191565189487)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 65 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.20143585565767333, 'gamma_dist_max': 0.4235191565189487})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.14688854555575498, 0.9520303793547092)
# for (gamma_dist_interval=(0.14688854555575498, 0.9520303793547092)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 64 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.14688854555575498, 'gamma_dist_max': 0.9520303793547092})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.009044091936970682, 0.5324187132827064)
# for (gamma_dist_interval=(0.009044091936970682, 0.5324187132827064)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 63 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.009044091936970682, 'gamma_dist_max': 0.5324187132827064})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.27625000435379554, 0.7575596262344074)
# for (gamma_dist_interval=(0.27625000435379554, 0.7575596262344074)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 62 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.27625000435379554, 'gamma_dist_max': 0.7575596262344074})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.22852125314846042, 0.4351239708842696)
# for (gamma_dist_interval=(-0.22852125314846042, 0.4351239708842696)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 61 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.22852125314846042, 'gamma_dist_max': 0.4351239708842696})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.2946996417525792, 0.6108865211867739)
# for (gamma_dist_interval=(-0.2946996417525792, 0.6108865211867739)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 60 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.2946996417525792, 'gamma_dist_max': 0.6108865211867739})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.33443360583953624, 0.5443027435226095)
# for (gamma_dist_interval=(-0.33443360583953624, 0.5443027435226095)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 59 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.33443360583953624, 'gamma_dist_max': 0.5443027435226095})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.3573912416978716, 0.7098461458064456)
# for (gamma_dist_interval=(-0.3573912416978716, 0.7098461458064456)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 58 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.3573912416978716, 'gamma_dist_max': 0.7098461458064456})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.3534342235651304, 0.5869618037323158)
# for (gamma_dist_interval=(-0.3534342235651304, 0.5869618037323158)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 57 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.3534342235651304, 'gamma_dist_max': 0.5869618037323158})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.32757562916820626, 0.944423885748348)
# for (gamma_dist_interval=(-0.32757562916820626, 0.944423885748348)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 56 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.32757562916820626, 'gamma_dist_max': 0.944423885748348})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.23390593855789876, 0.485892204908029)
# for (gamma_dist_interval=(0.23390593855789876, 0.485892204908029)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 55 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.23390593855789876, 'gamma_dist_max': 0.485892204908029})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.49042930126310036, 0.5153525305935714)
# for (gamma_dist_interval=(-0.49042930126310036, 0.5153525305935714)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 54 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.49042930126310036, 'gamma_dist_max': 0.5153525305935714})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.2276579798043581, 0.845237567178788)
# for (gamma_dist_interval=(-0.2276579798043581, 0.845237567178788)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 53 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.2276579798043581, 'gamma_dist_max': 0.845237567178788})>
# Launching 1 jobs with new suggestions
#  50%|█████     | 50/100 [00:00<00:00, 118.90it/s]
# Starting cost evaluation for gamma_dist_interval=(-0.24082507792383073, 0.6049940225733135)
# for (gamma_dist_interval=(-0.24082507792383073, 0.6049940225733135)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 52 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.24082507792383073, 'gamma_dist_max': 0.6049940225733135})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.36401254296890684, 0.7528279328095888)
# for (gamma_dist_interval=(-0.36401254296890684, 0.7528279328095888)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 51 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.36401254296890684, 'gamma_dist_max': 0.7528279328095888})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.31711037174417106, 0.7102554195488112)
# for (gamma_dist_interval=(-0.31711037174417106, 0.7102554195488112)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 50 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.31711037174417106, 'gamma_dist_max': 0.7102554195488112})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.223067260482163, 0.7547728245586037)
# for (gamma_dist_interval=(0.223067260482163, 0.7547728245586037)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 49 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.223067260482163, 'gamma_dist_max': 0.7547728245586037})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.08307656348044354, 0.992807300043457)
# for (gamma_dist_interval=(0.08307656348044354, 0.992807300043457)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 48 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.08307656348044354, 'gamma_dist_max': 0.992807300043457})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.06787938367973347, 0.6493039903232811)
# for (gamma_dist_interval=(0.06787938367973347, 0.6493039903232811)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 47 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.06787938367973347, 'gamma_dist_max': 0.6493039903232811})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.14924065840889847, 0.24831496193948055)
#  62%|██████▏   | 62/100 [00:00<00:00, 95.57it/s]
# for (gamma_dist_interval=(0.14924065840889847, 0.24831496193948055)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 46 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.14924065840889847, 'gamma_dist_max': 0.24831496193948055})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.03087895681301852, 0.06926737285472322)
# for (gamma_dist_interval=(0.03087895681301852, 0.06926737285472322)) ler per round, per qubit=8e-05
# errors: {'rotated_surface_code_memory_Z': np.int64(5)}, total (mem-bp failing) shots: 10000, percent error: 49.989998999799944%
# Updating fitness with value 8e-05
# 45 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.14924065840889847, 'gamma_dist_max': 0.24831496193948055})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.08996984623703068, 0.9732084001274802)
# for (gamma_dist_interval=(0.08996984623703068, 0.9732084001274802)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 44 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.08996984623703068, 'gamma_dist_max': 0.9732084001274802})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.39394381781393795, 0.9612293443725257)
# for (gamma_dist_interval=(-0.39394381781393795, 0.9612293443725257)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 43 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.39394381781393795, 'gamma_dist_max': 0.9612293443725257})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.40545013479735326, 0.6985192389078934)
# for (gamma_dist_interval=(-0.40545013479735326, 0.6985192389078934)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 42 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.40545013479735326, 'gamma_dist_max': 0.6985192389078934})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.40994505644914736, 0.8910636032521138)
# for (gamma_dist_interval=(-0.40994505644914736, 0.8910636032521138)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 41 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.40994505644914736, 'gamma_dist_max': 0.8910636032521138})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.05285601676252409, 0.6601203607594668)
# for (gamma_dist_interval=(-0.05285601676252409, 0.6601203607594668)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 40 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.05285601676252409, 'gamma_dist_max': 0.6601203607594668})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.006124639889371028, 0.49611163457198715)
# for (gamma_dist_interval=(0.006124639889371028, 0.49611163457198715)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 39 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.006124639889371028, 'gamma_dist_max': 0.49611163457198715})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.1695959452779485, 0.5327853014431193)
# for (gamma_dist_interval=(-0.1695959452779485, 0.5327853014431193)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 38 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.1695959452779485, 'gamma_dist_max': 0.5327853014431193})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.4313587278466843, 0.9743058242203034)
# for (gamma_dist_interval=(0.4313587278466843, 0.9743058242203034)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 37 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.4313587278466843, 'gamma_dist_max': 0.9743058242203034})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.3500084774530265, 0.6208670510641942)
# for (gamma_dist_interval=(0.3500084774530265, 0.6208670510641942)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 36 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.3500084774530265, 'gamma_dist_max': 0.6208670510641942})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.14688854555575498, 0.3809838123167025)
# for (gamma_dist_interval=(0.14688854555575498, 0.3809838123167025)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 35 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.14688854555575498, 'gamma_dist_max': 0.3809838123167025})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.1193196548319981, 0.5324187132827064)
#  73%|███████▎  | 73/100 [00:00<00:00, 87.23it/s]
# for (gamma_dist_interval=(0.1193196548319981, 0.5324187132827064)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 34 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.1193196548319981, 'gamma_dist_max': 0.5324187132827064})>
# Launching 1 jobs with new suggestions
# ...
# for (gamma_dist_interval=(0.19153772235728456, 0.9354721509502653)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 20 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.19153772235728456, 'gamma_dist_max': 0.9354721509502653})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.1388712414855959, 0.7547728245586037)
# for (gamma_dist_interval=(0.1388712414855959, 0.7547728245586037)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 19 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.1388712414855959, 'gamma_dist_max': 0.7547728245586037})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.36837173119812555, 0.992807300043457)
# for (gamma_dist_interval=(0.36837173119812555, 0.992807300043457)) ler per round, per qubit=4e-05
# errors: {'rotated_surface_code_memory_Z': np.int64(3)}, total (mem-bp failing) shots: 10000, percent error: 70.70360669725414%
# Updating fitness with value 4e-05
# 18 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.1388712414855959, 'gamma_dist_max': 0.7547728245586037})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.06787938367973347, 0.5953491805913587)
# for (gamma_dist_interval=(0.06787938367973347, 0.5953491805913587)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 17 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.06787938367973347, 'gamma_dist_max': 0.5953491805913587})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.2660298353788466, 0.7744514092967231)
# for (gamma_dist_interval=(0.2660298353788466, 0.7744514092967231)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 16 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.2660298353788466, 'gamma_dist_max': 0.7744514092967231})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.39381285989059545, 0.8537942459346533)
# for (gamma_dist_interval=(0.39381285989059545, 0.8537942459346533)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 15 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.39381285989059545, 'gamma_dist_max': 0.8537942459346533})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.479203112471939, 0.6825954783021084)
#  86%|████████▌ | 86/100 [00:00<00:00, 93.62it/s]
# for (gamma_dist_interval=(0.479203112471939, 0.6825954783021084)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
#  96%|█████████▌| 96/100 [00:00<00:00, 90.34it/s]
# Updating fitness with value 0.0
# 14 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.479203112471939, 'gamma_dist_max': 0.6825954783021084})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.39394381781393795, 0.8581703930033833)
# for (gamma_dist_interval=(-0.39394381781393795, 0.8581703930033833)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 13 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.39394381781393795, 'gamma_dist_max': 0.8581703930033833})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.28370015262673187, 0.6985192389078934)
# for (gamma_dist_interval=(-0.28370015262673187, 0.6985192389078934)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 12 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.28370015262673187, 'gamma_dist_max': 0.6985192389078934})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.29901369373052417, 0.8910636032521138)
# for (gamma_dist_interval=(0.29901369373052417, 0.8910636032521138)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 11 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.29901369373052417, 'gamma_dist_max': 0.8910636032521138})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.46049958564479687, 0.6829488712848594)
# for (gamma_dist_interval=(0.46049958564479687, 0.6829488712848594)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 10 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.46049958564479687, 'gamma_dist_max': 0.6829488712848594})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.48636769179143424, 0.4961116345719872)
# for (gamma_dist_interval=(0.48636769179143424, 0.4961116345719872)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 9 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.48636769179143424, 'gamma_dist_max': 0.4961116345719872})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.16959594527794847, 0.7400179060748177)
# for (gamma_dist_interval=(-0.16959594527794847, 0.7400179060748177)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 8 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.16959594527794847, 'gamma_dist_max': 0.7400179060748177})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.27322789199577063, 0.9743058242203034)
# for (gamma_dist_interval=(0.27322789199577063, 0.9743058242203034)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 7 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.27322789199577063, 'gamma_dist_max': 0.9743058242203034})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(0.45749379786116645, 0.6208670510641942)
# for (gamma_dist_interval=(0.45749379786116645, 0.6208670510641942)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 6 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': 0.45749379786116645, 'gamma_dist_max': 0.6208670510641942})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.014652482419600526, 0.31717132037522855)
# for (gamma_dist_interval=(-0.014652482419600526, 0.31717132037522855)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 5 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.014652482419600526, 'gamma_dist_max': 0.31717132037522855})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.3298512184219601, 0.16224359302245292)
# for (gamma_dist_interval=(-0.3298512184219601, 0.16224359302245292)) ler per round, per qubit=2e-05
# errors: {'rotated_surface_code_memory_Z': np.int64(2)}, total (mem-bp failing) shots: 10000, percent error: 99.99499987499374%
# Updating fitness with value 2e-05
# 4 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.014652482419600526, 'gamma_dist_max': 0.31717132037522855})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.25188016054850604, 0.9437315915001739)
# for (gamma_dist_interval=(-0.25188016054850604, 0.9437315915001739)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(1)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 3 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.25188016054850604, 'gamma_dist_max': 0.9437315915001739})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.2694217854047133, 0.5512746249501694)
# for (gamma_dist_interval=(-0.2694217854047133, 0.5512746249501694)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 2 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.2694217854047133, 'gamma_dist_max': 0.5512746249501694})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.19367063707301888, 0.6108865211867739)
# for (gamma_dist_interval=(-0.19367063707301888, 0.6108865211867739)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 1 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.19367063707301888, 'gamma_dist_max': 0.6108865211867739})>
# Launching 1 jobs with new suggestions
# Starting cost evaluation for gamma_dist_interval=(-0.23862016864903934, 0.5443027435226097)
# for (gamma_dist_interval=(-0.23862016864903934, 0.5443027435226097)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Updating fitness with value 0.0
# 0 remaining budget and 0 running jobs
# Current pessimistic best is: MultiValue<mean: 0.0, count: 1, parameter: Instrumentation(Tuple(),Dict(gamma_dist_max=Scalar{Cl(0,1,b)}[sigma=Scalar{exp=2.03}],gamma_dist_min=Scalar{Cl(-0.5,0.5,b)}[sigma=Scalar{exp=2.03}])):((), {'gamma_dist_min': -0.23862016864903934, 'gamma_dist_max': 0.5443027435226097})>
# Starting cost evaluation for gamma_dist_interval=(-0.23862016864903934, 0.5443027435226097)
# for (gamma_dist_interval=(-0.23862016864903934, 0.5443027435226097)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# Starting cost evaluation for gamma_dist_interval=(-0.23862016864903934, 0.5443027435226097)
# for (gamma_dist_interval=(-0.23862016864903934, 0.5443027435226097)) ler per round, per qubit=0.0
# errors: {'rotated_surface_code_memory_Z': np.int64(0)}, total (mem-bp failing) shots: 10000, percent error: 100.0%
# For d=5 relay-bp optimization with p=0.001
# Expedited cost function logical error rate: 0.0
# Full cost function logical error rate: 0.0
# optimized parameters - opt_gamma0: 0.30000000000000004, opt_gamma_dist_interval: [-0.23862016864903934, 0.5443027435226097]

# %% [markdown]
# ## Performing a detailed error rate characterization
#
# We now perform a dertailed error rate sweep using the (best) values we found for Relay.
# We examine the performance with both XZ and XYZ decoding.
# We include `msl-bp` (with a large number of iteratios) and `pymatching` for reference.

# %%
# Ensure consistent comparison
if not optimize:
    best_relay_gamma_dist = relay_gamma_dist_interval
    best_gamma0 = gamma0
    print(f"Relay parameter optimization was skipped. Using default values specificed at top of notebook - gamma0: {best_gamma0}, gamma dist: {best_relay_gamma_dist}")
else:
    best_gamma0 = min_gamma0
    best_relay_gamma_dist = opt_gamma_dist_interval
    print(f"Using Relay parameters obtained from gradient free optimization")
    print(f"Using the best discount factor: {best_gamma0} and optimized memory factor disorder distribution: {best_relay_gamma_dist} with ler per round: {opt_ler}")
# Out:
# Using Relay parameters obtained from gradient free optimization
# Using the best discount factor: 0.30000000000000004 and optimized memory factor disorder distribution: [-0.23862016864903934, 0.5443027435226097] with ler per round: 0.0

# %%
def generate_plot_tasks_xz(relay_params, mem_params, msl_params):
    for p in error_rates:
        for circuit_name in circuits:
            circ = testdata.get_test_circuit(circuit_name, distance=distance, rounds=rounds, error_rate=p)
            circ = testdata.filter_detectors_by_basis(circ, circuit_name[-1])
            dem = circ.detector_error_model(decompose_errors=True)
            
            for decoder in all_decoders:
                json_metadata = {
                        'circuit': circuit_name,
                        'p': p,
                        'd': distance,
                        'xyz': False,
                        'decoder_params': {}
                }
                num_shots = select_num_shots(p)
                if decoder == "relay-bp":
                    json_metadata["decoder_params"] = relay_params
                elif decoder == "mem-bp":
                    json_metadata["decoder_params"] = mem_params
                    num_shots = rough_select_num_shots(p)
                elif decoder == "msl-bp":
                    json_metadata["decoder_params"] = msl_params
                    num_shots = rough_select_num_shots(p)
                
                yield sinter.Task(
                    circuit=circ,
                    detector_error_model=dem,
                    decoder=decoder,
                    json_metadata=json_metadata,
                    collection_options=sinter.CollectionOptions(max_shots=num_shots)
                )

def generate_plot_tasks_xyz(relay_params, mem_params, msl_params):
    for p in error_rates:
        for circuit_name in circuits:
            circ = testdata.get_test_circuit(circuit_name, distance=distance, rounds=rounds, error_rate=p)
            dem = circ.detector_error_model(decompose_errors=False)
        
            for decoder in all_decoders:
                if decoder in xz_only_decoders:
                    continue
                json_metadata = {
                        'circuit': circuit_name,
                        'p': p,
                        'd': distance,
                        'xyz': True,
                        'decoder_params': {}
                }
                num_shots = select_num_shots(p)
                if decoder == "relay-bp":
                    json_metadata["decoder_params"] = relay_params
                elif decoder == "mem-bp":
                    json_metadata["decoder_params"] = mem_params
                    num_shots = rough_select_num_shots(p)
                elif decoder == "msl-bp":
                    json_metadata["decoder_params"] = msl_params
                    num_shots = rough_select_num_shots(p)
        
                yield sinter.Task(
                    circuit=circ,
                    detector_error_model=dem,
                    decoder=decoder,
                    json_metadata=json_metadata,
                    collection_options=sinter.CollectionOptions(max_shots=num_shots)
                )



def collect_samples(relay_params, mem_params, msl_params):
    samples = []

    custom_decoders = {
        "relay-bp": SinterDecoder_RelayBP(**relay_params),
        "mem-bp": SinterDecoder_MemBP(**mem_params), 
        "msl-bp": SinterDecoder_MSLBP(**msl_params), 
    }
    samples += sinter_collect(
            itertools.chain(generate_plot_tasks_xz(relay_params, mem_params, msl_params), generate_plot_tasks_xyz(relay_params, mem_params, msl_params)), 
            exp_name="fine_ler_sweep", 
            custom_decoders=custom_decoders,
            print_progress=True,
            save=save_data,
            load=load_data,
        )
    return samples

relay_params = build_relay_params(gamma0=best_gamma0, gamma_dist_interval=best_relay_gamma_dist)
mem_params = build_mem_params(gamma0=best_gamma0)
msl_params = build_msl_params()
# Collect the samples
fine_ler_sweep_samples_separated_basis = collect_samples(relay_params, mem_params, msl_params)
fine_ler_sweep_samples = testdata.synthesize_joint_samples(fine_ler_sweep_samples_separated_basis, circuits)
# Out:
# Starting 20 workers...
# 21 tasks left:
#   workers    decoder eta shots_taken errors_seen json_metadata
#         1   relay-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=False,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1     mem-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1     msl-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         1 pymatching   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=False,decoder_params={}
#         1   relay-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=False,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1     mem-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1     msl-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         1 pymatching   ?        1297           1 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=False,decoder_params={}
#         1   relay-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=False,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1     mem-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1     msl-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         1 pymatching   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=False,decoder_params={}
#         1   relay-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1     mem-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1     msl-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         1   relay-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1     mem-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1     msl-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         1   relay-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1     mem-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         0     msl-bp ?·∞           0           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 16 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         2 relay-bp   ?        1298           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=False,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?        3618           1 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?        1297           5 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?        2321           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=False,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1   mem-bp   ?        1297           3 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1   msl-bp   ?         273           2 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         1   msl-bp   ?         273           5 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         1 relay-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1   mem-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1   msl-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         1 relay-bp   ?           1           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1   mem-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1   msl-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         1 relay-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1   mem-bp   ?          17           1 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1   msl-bp   ?           0           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 14 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         2 relay-bp   ?        7969           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=False,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?        7714           3 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?        5666          12 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2   mem-bp   ?        2594           9 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?        2321          11 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1   mem-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1   msl-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         1 relay-bp   ?           1           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1   mem-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1   msl-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         1 relay-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1   mem-bp   ?          17           1 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1   msl-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 11 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         2   msl-bp   ?        9505          17 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2   msl-bp   ?        4489          20 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=False,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?           1           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         1   mem-bp   ?         273           3 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         1   msl-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 9 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         3 relay-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   mem-bp   ?        1298           1 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?           1           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?         273           3 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 9 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         3 relay-bp   ?        1299           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   mem-bp   ?        1843           1 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?           1           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?         273           3 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?          17           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 9 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         3 relay-bp   ?        1843           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   mem-bp   ?        1843           1 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?           1           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         274           2 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?         274           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?         786           9 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         146           3 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 9 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         3 relay-bp   ?        1843           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   mem-bp   ?        2867           1 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?         274           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?        1314           3 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         274           2 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?         274           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?        1000          12 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         162           4 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 8 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         3 relay-bp   ?        2867           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   mem-bp   ?        4915           3 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         3   msl-bp   ?         273           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         3 relay-bp   ?         274           0 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?        1314           3 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         274           2 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?         274           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   msl-bp   ?         162           4 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 8 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         3 relay-bp   ?        4915           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   mem-bp   ?        5580           3 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         3   msl-bp   ?        1299           1 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         3 relay-bp   ?         803           1 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?        1570           8 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         274           2 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?         274           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   msl-bp   ?         162           4 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 8 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         3 relay-bp   ?        4915           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   mem-bp   ?        6604           3 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         3   msl-bp   ?        1299           1 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         3 relay-bp   ?        1075           2 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?        1570           8 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         546           4 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?         510           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   msl-bp   ?         226           4 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 8 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         3 relay-bp   ?        5939           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   mem-bp   ?        7628           3 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         3   msl-bp   ?        1299           1 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         3 relay-bp   ?        1075           2 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?        1570           8 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         802           9 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?         637           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   msl-bp   ?         226           4 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 8 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         3 relay-bp   ?        6604           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   mem-bp   ?        8528           4 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         3   msl-bp   ?        1299           1 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         3 relay-bp   ?        1075           2 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   mem-bp   ?        3106          10 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         2   msl-bp   ?         802           9 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         2 relay-bp   ?         637           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   msl-bp   ?         226           4 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 8 tasks left:
# ...
#         3   msl-bp   ?        1059          11 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         3 relay-bp   ?         954           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   msl-bp   ?         482          11 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 7 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         3 relay-bp   ?        9586           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   msl-bp   ?        2099           4 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         3 relay-bp   ?        2202           2 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   mem-bp   ?        4857          13 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200, 'gamma0': np.float64(0.30000000000000004)}
#         3   msl-bp   ?        1075          11 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         3 relay-bp   ?         954           0 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         2   msl-bp   ?         610          11 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 6 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         4 relay-bp   ?        9586           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   msl-bp   ?        2611           7 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         3 relay-bp   ?        3226           3 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         3   msl-bp   ?        1331          12 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         3 relay-bp   ?        1000           1 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         4   msl-bp   ?         610          11 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 5 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         4 relay-bp   ?        9586           0 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         4   msl-bp   ?        3635           9 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         4 relay-bp   ?        3226           3 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         4   msl-bp   ?        1459          12 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         4   msl-bp   ?         610          11 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 5 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         4 relay-bp   ?       10000           1 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         4   msl-bp   ?        3908          10 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         4 relay-bp   ?        3602           3 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         4   msl-bp   ?        1476          12 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         4   msl-bp   ?         763          15 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 4 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         5   msl-bp   ?        4164          10 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         5 relay-bp   ?        4115           4 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         5   msl-bp   ?        1732          14 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         5   msl-bp   ?         912          19 circuit=rotated_surface_code_memory_Z,p=0.003,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 3 tasks left:
#   workers  decoder eta shots_taken errors_seen json_metadata
#         6   msl-bp   ?        4181          10 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#         7 relay-bp   ?        4579           4 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'gamma0': np.float64(0.30000000000000004), 'gamma_dist_interval': [-0.23862016864903934, 0.5443027435226097], 'num_sets': 60, 'pre_iter': 80, 'set_max_iter': 60, 'stop_nconv': 1}
#         7   msl-bp   ?        2005          18 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 2 tasks left:
#   workers decoder eta shots_taken errors_seen json_metadata
#        10  msl-bp   ?        4702          11 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#        10  msl-bp   ?        2278          19 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 2 tasks left:
#   workers decoder eta shots_taken errors_seen json_metadata
#        10  msl-bp   ?        5470          13 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#        10  msl-bp   ?        2310          20 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 2 tasks left:
#   workers decoder eta shots_taken errors_seen json_metadata
#        10  msl-bp   ?        5821          13 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#        10  msl-bp   ?        2709          24 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 2 tasks left:
#   workers decoder eta shots_taken errors_seen json_metadata
#        10  msl-bp   ?        7246          17 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#        10  msl-bp   ?        3195          26 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 2 tasks left:
#   workers decoder eta shots_taken errors_seen json_metadata
#        10  msl-bp   ?        8810          18 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#        10  msl-bp   ?        3707          28 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 2 tasks left:
#   workers decoder eta shots_taken errors_seen json_metadata
#        10  msl-bp   ?        9403          19 circuit=rotated_surface_code_memory_Z,p=0.001,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
#        10  msl-bp   ?        3995          29 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 1 tasks left:
#   workers decoder eta shots_taken errors_seen json_metadata
#        20  msl-bp   ?        4845          36 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}
# 1 tasks left:
#   workers decoder eta shots_taken errors_seen json_metadata
#        20  msl-bp   ?        5000          39 circuit=rotated_surface_code_memory_Z,p=0.002,d=5,xyz=True,decoder_params={'alpha': 1.0, 'max_iter': 200}

# %%
def group_func(stat):
    return {
        "label": f'{stat.decoder}(XYZ={stat.json_metadata["xyz"]})',
        "color": stat.decoder,
        "linestyle": "--" if stat.json_metadata["xyz"] else  "-",
    }

def filter_func(stat):
    to_return = (
            "xyz" in stat.json_metadata and 
            stat.json_metadata["p"] in error_rates and
            stat.json_metadata["d"] == distance)
    if stat.decoder == "relay-bp":
            return stat.json_metadata["decoder_params"] == relay_params and to_return
    elif stat.decoder == "mem-bp":
            return stat.json_metadata["decoder_params"] == mem_params and to_return   
    elif stat.decoder == "msl-bp":
            return stat.json_metadata["decoder_params"] == msl_params and to_return   
    return to_return

# Render a matplotlib plot of the data.
fig, ax = plt.subplots(1, 1, figsize=(10, 8))

sinter.plot_error_rate(
    ax=ax,
    stats=fine_ler_sweep_samples,
    failure_units_per_shot_func=lambda stats: stats.json_metadata['d'],
    group_func=group_func,
    x_func=lambda stat: stat.json_metadata['p'],
    filter_func=filter_func,
)

ax.loglog()
ax.grid()
ax.set_title(f'{notebook_str} - Logical Error Rate vs Physical Error Rate for Optimized Relay Parameters (d={distance} p={opt_error_rate} shots={opt_max_shots})')
ax.set_ylabel('Logical Error Probability (per round/qubit)')
ax.set_xlabel('Physical Error Rate')
ax.legend()

plt.show()

# %%
import math
def stderr(stat):
    stderr_mean = math.sqrt(stat.errors/stat.shots*(1-stat.errors/stat.shots))*math.sqrt(1/stat.shots)
    ler_stderr = 1-(1-stderr_mean)**(1/stat.json_metadata["d"])
    return ler_stderr

def print_decoder_outputs(samples):
    samples = [sample for sample in samples if filter_func(sample)]
    groups = sinter.group_by(samples, key=lambda stat: (stat.decoder, stat.json_metadata["xyz"]))
    
    for decoder, stats in groups.items():
        stats = sorted(stats, key=lambda stat: stat.json_metadata["p"])
        lers = sorted([1-(1-stat.errors/stat.shots)**(1/stat.json_metadata["d"]) for stat in stats])
        ler_stderrs = sorted([stderr(stat) for stat in stats])
        #lers, ler_stderrs = [ler_stderr(stat) for stat in stats]
        print(f"(Decoder, XYZ): {decoder} --- LERS: {lers} -- stderrs: {ler_stderrs}")
        
print_decoder_outputs(fine_ler_sweep_samples)
# Out:
# (Decoder, XYZ): ('pymatching', False) --- LERS: [0.0, 0.000200080048033624, 0.00120289041174515] -- stderrs: [0.0, 8.941397484263369e-05, 0.0004889038638424825]
# (Decoder, XYZ): ('mem-bp', False) --- LERS: [6.0007201296286006e-05, 0.000600721298727791, 0.0014039365451051777] -- stderrs: [3.463821913851639e-05, 0.0001547346585214493, 0.0005278519451376029]
# (Decoder, XYZ): ('relay-bp', False) --- LERS: [0.0, 0.000200080048033624, 0.0004003203845384107] -- stderrs: [0.0, 8.941397484263369e-05, 0.0002827195436906349]
# (Decoder, XYZ): ('msl-bp', False) --- LERS: [0.0004003203845384107, 0.0009618485263176435, 0.0028158130166671125] -- stderrs: [8.936920389646108e-05, 0.00019556478788607112, 0.0007441814816164793]
# (Decoder, XYZ): ('relay-bp', True) --- LERS: [0.0, 0.0001600512245897301, 0.000200080048033624] -- stderrs: [0.0, 7.998078642657003e-05, 0.00019997994294906896]
# (Decoder, XYZ): ('mem-bp', True) --- LERS: [6.0007201296286006e-05, 0.000600721298727791, 0.0024116036471454327] -- stderrs: [3.463821913851639e-05, 0.0001547346585214493, 0.0006896012991830514]
# (Decoder, XYZ): ('msl-bp', True) --- LERS: [0.0004003203845384107, 0.0015648901036084961, 0.004235731168636292] -- stderrs: [8.936920389646108e-05, 0.0002489477121481176, 0.0009084898783254802]
# 100%|██████████| 100/100 [00:19<00:00, 90.34it/s]
